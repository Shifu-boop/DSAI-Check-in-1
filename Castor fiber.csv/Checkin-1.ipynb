# %% [markdown]
# ## 1. Project goal
#
# Our selected species is: [species name]
#
# Business objective:
# [Explain the real-world goal. For example: understanding habitat suitability, predicting spread risk, predicting population presence, etc.]
#
# data management goals (DMGs):
# We want to predict/classify [target variable] using the available dataset.
#
# This is a [regression/classification] problem because [explain why].

# %% [markdown]
# ## 2. Dataset overview

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ### 3. Target variable

# %% [markdown]
# ### 4. Missing values

# %% [markdown]
# ### 5. Distributions

# %% [markdown]
# ### 6. Outliers

# %% [markdown]
# ### 7. Correlations with target

# %% [markdown]
# ### 8. Multicollinearity

# %% [markdown]
# ### 9. Transformations and scaling

# %% [markdown]
# ### 10. Preparation decisions and next steps
